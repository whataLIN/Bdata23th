# %% [markdown]
# <a href="https://colab.research.google.com/github/suhdongjoon/Python_sdj/blob/main/MyFirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World") # Ctrl + Enter
# Out:
# Hello World

# %%
print(Hello world)

# %%
print"Hello World"
