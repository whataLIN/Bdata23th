# %% [markdown]
# <a href="https://colab.research.google.com/github/JaejinLee1215/Python_LJJ/blob/main/ch01_03_%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 제목 (Headline)
# ## 2단계 제목
# ### 3단계 제목
# #### 4단계 제목
# ##### 5단계 제목
# ###### 6단계 제목

# %% [markdown]
# 수평선
# ---
# 텍스트에 ---를 바로 붙이면 '#'과 같은 효과
#
# (수평선)
#
# ---

# %% [markdown]
# 줄바꿈<br>줄바꿈

# %% [markdown]
# **굵게**
# *기울게*
# __굵게__
# ~~취소선~~
# <u>밑줄</u>
# <mark>형광펜</mark>

# %% [markdown]
# > 인용문
# >> 인용문 안에 인용문
# >>> 인용문 안에 인용문 안에 인용문
# >>>> 인용문 안에 인용문 안에 인용문 안에 인용문

# %% [markdown]
# 순서가 없는 리스트
# * 사과
# * 배
# * 자두
#
# 순서가 있는 리스트
# 1. Python
# 2. JAVA
# 3. SQL
#
# 순서가 있는 리스트2
# 1. Python
# 1. JAVA
# 1. SQL
#
# 들여쓰기
# * 사과
#   * 껍질
#     * 볶음
# * 위
#       아래 (Tab * 2 = 코드블록)
#       **굵게**
#
# 코드 블록 -> 이 안에 꾸며주는 마크다운 문법 무시 ex)굵게

# %% [markdown]
# #코드 블록
#
# 한 줄 코드
# `print('hello World')` - 음영처리
#
# 여러 줄 코드블록
#
# ```
# print("hello")
# print("world")
# ```

# %% [markdown]
# #테이블 만들기
#
# |제목|작가|출판일|
# |-|-|-|
# |장발장|이재진|2023|
# |파이썬|이재진|2023|
# |JAVA|이재진|2023|
#
# |제목|작가|출판일|
# |-|-|-|
# |**장발장**|이재진|2023|
# |파이썬|이재진|2023|
# |JAVA|~이재진~|2023|
#
# |-|-|-| : 가운데 정렬
# |:-|:-|:-| : 왼쪽 정렬
# |-:|-:|-:| : 오른쪽 정렬

# %% [markdown]
# [표시될 링크 제목](http://naver.com)
# ![](https://cdn.pixabay.com/photo/2023/02/08/07/32/vietnamese-woman-7775904_960_720.jpg)
#
# [] : 링크
# ![] : 이미지를 불러온다

# %% [markdown]
# - [ ] 체크박스
# - [x] 체크된 픽스박스
