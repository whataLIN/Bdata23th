# %% [markdown]
# <a href="https://colab.research.google.com/github/CHOISEONGGU/Python_SG/blob/main/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World") # ctrl + Enter - 실행키
# Out:
# Hello World
